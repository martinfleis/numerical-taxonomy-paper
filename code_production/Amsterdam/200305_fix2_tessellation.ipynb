# %%
import geopandas as gpd

# %%
tess = gpd.read_file('/Users/martin/Dropbox/Academia/Data/Geo/Amsterdam/queen.gpkg')

# %%
validity = tess.is_valid

# %%
invalid = tess[~validity]

# %%
invalid
# Out:
#            uID                                           geometry
# 19426    19440  POLYGON ((129146.403 484174.777, 129212.200 48...
# 19433    19449  POLYGON ((129324.707 484166.833, 129272.322 48...
# 19434    19450  POLYGON ((129327.283 484168.372, 129275.922 48...
# 61827    61879  POLYGON ((119459.775 486447.097, 119459.587 48...
# 89188    89265  POLYGON ((121793.326 485686.579, 121793.103 48...
# 115635  115742  POLYGON ((123043.512 486728.641, 123043.967 48...
# 118791  118902  POLYGON ((124694.401 487253.716, 124694.392 48...
# 163791  163931  POLYGON ((116422.661 483648.215, 116423.015 48...
# 172621  172773  POLYGON ((109276.471 475090.592, 109269.288 47...

# %%
invalid.plot()

# %%
g = invalid.geometry.loc[61827]

# %%
g.buffer(0)

# %%
invalid.geometry.loc[172621].buffer(0)
