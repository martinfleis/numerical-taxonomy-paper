# %% [markdown]
# # Measure contextualised characters
#
# date: 2020-03-07 Amsterdam Data

# %%
import geopandas as gpd
import momepy as mm
from tqdm import tqdm
from momepy import limit_range
import numpy as np
import pandas as pd
from pysal.explore.inequality.theil import Theil
import libpysal
import scipy as sp
# Out:
# /home/arch_ubuntu/miniconda/envs/momepy_env/lib/python3.7/site-packages/pysal/explore/segregation/network/network.py:16: UserWarning: You need pandana and urbanaccess to work with segregation's network module
# You can install them with  `pip install urbanaccess pandana` or `conda install -c udst pandana urbanaccess`
#   "You need pandana and urbanaccess to work with segregation's network module\n"
# /home/arch_ubuntu/miniconda/envs/momepy_env/lib/python3.7/site-packages/pysal/model/spvcm/abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
gdf = pd.read_csv('files/AMS/primary.csv', index_col=0)

# %%
spatial_weights = libpysal.io.open('files/AMS/AMSqueen3.gal', 'r').read()
spatial_weights.neighbors = {int(k): [int(i) for i in v] for k, v in spatial_weights.neighbors.items()}
# Out:
# /home/arch_ubuntu/miniconda/envs/momepy_env/lib/python3.7/site-packages/libpysal/weights/weights.py:165: UserWarning: The weights matrix is not fully connected:
#  There are 148 disconnected components.
#   warnings.warn(message)

# %%
gdf.set_index('uID', inplace=True)

# %%
gdf
# Out:
#           stcOri      sdcLAL        sdcAre    sscCCo    sscERI    sicCAR  \
# uID
# 0      27.510060  216.792883  28760.794790  0.779150  1.081927  0.004502
# 1      27.569911  214.663688  27868.518833  0.770029  1.080976  0.003202
# 2      26.780955  142.946654   4725.131782  0.294426  0.944924  0.063007
# 3      38.230240  184.595244  15683.586526  0.586023  1.018656  0.052321
# 4       9.362836  151.244275   6032.094361  0.335753  0.822057  0.082069
# ...          ...         ...           ...       ...       ...       ...
# 19452  32.905625  122.129802    678.408432  0.057911  0.799167  0.117692
# 19453  32.907696  119.689689   1907.120365  0.169502  0.895196  0.041436
# 19454  40.925191   26.664661    178.598830  0.319828  0.983183  0.285785
# 19455  42.884230   42.515494    888.019281  0.625515  1.006693  0.332357
# 19457  30.639729  121.086592   3299.599620  0.286536  0.996615  0.050976
#
#          sicFAR    mtcWNe        mdcAre    licGDe  ...       ldsCDL    xcnSCl  \
# uID                                                ...
# 0      0.004502  0.001577  56629.313623  0.003862  ...    39.617021  0.000000
# 1      0.003202  0.001599  56629.313623  0.003862  ...    39.617021  0.000000
# 2      0.063007  0.008920  43845.834221  0.025565  ...  3334.105306  0.000000
# 3      0.052321  0.006100  35810.564680  0.042358  ...  3334.105306  0.000000
# 4      0.082069  0.015487  84209.214520  0.025565  ...  3334.105306  0.000000
# ...         ...       ...           ...       ...  ...          ...       ...
# 19452  0.353076  0.011775   3549.480638  0.478379  ...    36.094747  0.333333
# 19453  0.124307  0.015075   6763.119547  1.016754  ...    36.094747  0.333333
# 19454  0.857355  0.079462   3261.843269  0.682345  ...    54.774919  0.035714
# 19455  1.329426  0.050626   7891.125350  0.682345  ...    36.094747  0.333333
# 19457  0.152927  0.017320  11139.207402  0.819609  ...    36.094747  0.333333
#
#             mtdMDi    lddNDe    linWID  lddRea         lddARe         sddAre  \
# uID
# 0      1292.397204  0.000000  0.000000    33.0  558410.517442   56629.313623
# 1      1292.397204  0.000000  0.000000    33.0  558410.517442   56629.313623
# 2      1566.836623  0.024562  0.049753    96.0  853610.178449  340966.253401
# 3      1566.836623  0.024562  0.049753    96.0  853610.178449  340966.253401
# 4      1566.836623  0.024562  0.049753    96.0  853610.178449  340966.253401
# ...            ...       ...       ...     ...            ...            ...
# 19452    90.941175  0.055412  0.109620    77.0  197239.194862   10262.154015
# 19453    90.941175  0.055412  0.109620    77.0  197239.194862   10262.154015
# 19454    94.820452  0.066672  0.122414   120.0  246336.056677   11429.168476
# 19455    90.941175  0.055412  0.109620    77.0  197239.194862   10262.154015
# 19457    90.941175  0.055412  0.109620    77.0  197239.194862   10262.154015
#
#        midRea         midAre
# uID
# 0         4.0  116032.091487
# 1         4.0  116032.091487
# 2        44.0  458284.275492
# 3        44.0  458284.275492
# 4        44.0  458284.275492
# ...       ...            ...
# 19452    18.0   49180.208879
# 19453    18.0   49180.208879
# 19454    28.0   53796.131602
# 19455    18.0   49180.208879
# 19457    18.0   49180.208879
#
# [252385 rows x 74 columns]

# %%
characters = gdf.columns

# %%
means = {}
ranges = {}
theils = {}

for ch in characters:
    means[ch] = []
    ranges[ch] = []
    theils[ch] = []

# %%
unique_id = 'uID'

# %%
gdf = gdf.fillna(0)

# %%
gdf['lcdMes'] = gdf.apply(
            lambda row: row.lcdMes if row.lcdMes >= 0 else 0,
            axis=1,
        )

# %%
def theil(y):
    y = np.array(y)
    n = len(y)
    plus = y + np.finfo('float').tiny * (y == 0)  # can't have 0 values
    yt = plus.sum(axis=0)
    s = plus / (yt * 1.0)
    lns = np.log(n * s)
    slns = s * lns
    t = sum(slns)
    return t


for index, row in tqdm(gdf.iterrows(), total=gdf.shape[0]):
    neighbours = spatial_weights.neighbors[index].copy()
    neighbours.append(index)
    
    for ch in characters:
        values_list = gdf.loc[neighbours][ch]        
        idec = limit_range(values_list.tolist(), rng=(10, 90))
        iquar = limit_range(values_list.tolist(), rng=(25, 75))
        
        means[ch].append(np.mean(iquar))
        ranges[ch].append(sp.stats.iqr(values_list, rng=(25, 75)))
        theils[ch].append(theil(idec))
# Out:
# 100%|██████████| 252385/252385 [7:49:41<00:00,  8.96it/s]

# %%
for ch in characters:
    gdf[ch + '_meanIQ3'] = means[ch]
    gdf[ch + '_rangeIQ3'] = ranges[ch]
    gdf[ch + '_theilID3'] = theils[ch]

# %%
pat = [x for x in gdf.columns if '_' in x]

# %%
pat
# Out:
# ['stcOri_meanIQ3',
#  'stcOri_rangeIQ3',
#  'stcOri_theilID3',
#  'sdcLAL_meanIQ3',
#  'sdcLAL_rangeIQ3',
#  'sdcLAL_theilID3',
#  'sdcAre_meanIQ3',
#  'sdcAre_rangeIQ3',
#  'sdcAre_theilID3',
#  'sscCCo_meanIQ3',
#  'sscCCo_rangeIQ3',
#  'sscCCo_theilID3',
#  'sscERI_meanIQ3',
#  'sscERI_rangeIQ3',
#  'sscERI_theilID3',
#  'sicCAR_meanIQ3',
#  'sicCAR_rangeIQ3',
#  'sicCAR_theilID3',
#  'sicFAR_meanIQ3',
#  'sicFAR_rangeIQ3',
#  'sicFAR_theilID3',
#  'mtcWNe_meanIQ3',
#  'mtcWNe_rangeIQ3',
#  'mtcWNe_theilID3',
#  'mdcAre_meanIQ3',
#  'mdcAre_rangeIQ3',
#  'mdcAre_theilID3',
#  'licGDe_meanIQ3',
#  'licGDe_rangeIQ3',
#  'licGDe_theilID3',
#  'ltcWRB_meanIQ3',
#  'ltcWRB_rangeIQ3',
#  'ltcWRB_theilID3',
#  'stcSAl_meanIQ3',
#  'stcSAl_rangeIQ3',
#  'stcSAl_theilID3',
#  'sdbHei_meanIQ3',
#  'sdbHei_rangeIQ3',
#  'sdbHei_theilID3',
#  'sdbAre_meanIQ3',
#  'sdbAre_rangeIQ3',
#  'sdbAre_theilID3',
#  'sdbVol_meanIQ3',
#  'sdbVol_rangeIQ3',
#  'sdbVol_theilID3',
#  'sdbPer_meanIQ3',
#  'sdbPer_rangeIQ3',
#  'sdbPer_theilID3',
#  'sdbCoA_meanIQ3',
#  'sdbCoA_rangeIQ3',
#  'sdbCoA_theilID3',
#  'ssbFoF_meanIQ3',
#  'ssbFoF_rangeIQ3',
#  'ssbFoF_theilID3',
#  'ssbVFR_meanIQ3',
#  'ssbVFR_rangeIQ3',
#  'ssbVFR_theilID3',
#  'ssbCCo_meanIQ3',
#  'ssbCCo_rangeIQ3',
#  'ssbCCo_theilID3',
#  'ssbCor_meanIQ3',
#  'ssbCor_rangeIQ3',
#  'ssbCor_theilID3',
#  'ssbSqu_meanIQ3',
#  'ssbSqu_rangeIQ3',
#  'ssbSqu_theilID3',
#  'ssbERI_meanIQ3',
#  'ssbERI_rangeIQ3',
#  'ssbERI_theilID3',
#  'ssbElo_meanIQ3',
#  'ssbElo_rangeIQ3',
#  'ssbElo_theilID3',
#  'stbOri_meanIQ3',
#  'stbOri_rangeIQ3',
#  'stbOri_theilID3',
#  'mtbSWR_meanIQ3',
#  'mtbSWR_rangeIQ3',
#  'mtbSWR_theilID3',
#  'mtbAli_meanIQ3',
#  'mtbAli_rangeIQ3',
#  'mtbAli_theilID3',
#  'mtbNDi_meanIQ3',
#  'mtbNDi_rangeIQ3',
#  'mtbNDi_theilID3',
#  'libNCo_meanIQ3',
#  'libNCo_rangeIQ3',
#  'libNCo_theilID3',
#  'ldbPWL_meanIQ3',
#  'ldbPWL_rangeIQ3',
#  'ldbPWL_theilID3',
#  'ltbIBD_meanIQ3',
#  'ltbIBD_rangeIQ3',
#  'ltbIBD_theilID3',
#  'ltcBuA_meanIQ3',
#  'ltcBuA_rangeIQ3',
#  'ltcBuA_theilID3',
#  'ssbCCM_meanIQ3',
#  'ssbCCM_rangeIQ3',
#  'ssbCCM_theilID3',
#  'ssbCCD_meanIQ3',
#  'ssbCCD_rangeIQ3',
#  'ssbCCD_theilID3',
#  'stbCeA_meanIQ3',
#  'stbCeA_rangeIQ3',
#  'stbCeA_theilID3',
#  'stbSAl_meanIQ3',
#  'stbSAl_rangeIQ3',
#  'stbSAl_theilID3',
#  'ldkAre_meanIQ3',
#  'ldkAre_rangeIQ3',
#  'ldkAre_theilID3',
#  'ldkPer_meanIQ3',
#  'ldkPer_rangeIQ3',
#  'ldkPer_theilID3',
#  'lskCCo_meanIQ3',
#  'lskCCo_rangeIQ3',
#  'lskCCo_theilID3',
#  'lskERI_meanIQ3',
#  'lskERI_rangeIQ3',
#  'lskERI_theilID3',
#  'lskCWA_meanIQ3',
#  'lskCWA_rangeIQ3',
#  'lskCWA_theilID3',
#  'ltkOri_meanIQ3',
#  'ltkOri_rangeIQ3',
#  'ltkOri_theilID3',
#  'ltkWNB_meanIQ3',
#  'ltkWNB_rangeIQ3',
#  'ltkWNB_theilID3',
#  'likWBB_meanIQ3',
#  'likWBB_rangeIQ3',
#  'likWBB_theilID3',
#  'sdsLen_meanIQ3',
#  'sdsLen_rangeIQ3',
#  'sdsLen_theilID3',
#  'sdsSPW_meanIQ3',
#  'sdsSPW_rangeIQ3',
#  'sdsSPW_theilID3',
#  'sdsSPH_meanIQ3',
#  'sdsSPH_rangeIQ3',
#  'sdsSPH_theilID3',
#  'sdsSPR_meanIQ3',
#  'sdsSPR_rangeIQ3',
#  'sdsSPR_theilID3',
#  'sdsSPO_meanIQ3',
#  'sdsSPO_rangeIQ3',
#  'sdsSPO_theilID3',
#  'sdsSWD_meanIQ3',
#  'sdsSWD_rangeIQ3',
#  'sdsSWD_theilID3',
#  'sdsSHD_meanIQ3',
#  'sdsSHD_rangeIQ3',
#  'sdsSHD_theilID3',
#  'sssLin_meanIQ3',
#  'sssLin_rangeIQ3',
#  'sssLin_theilID3',
#  'sdsAre_meanIQ3',
#  'sdsAre_rangeIQ3',
#  'sdsAre_theilID3',
#  'sisBpM_meanIQ3',
#  'sisBpM_rangeIQ3',
#  'sisBpM_theilID3',
#  'misRea_meanIQ3',
#  'misRea_rangeIQ3',
#  'misRea_theilID3',
#  'mdsAre_meanIQ3',
#  'mdsAre_rangeIQ3',
#  'mdsAre_theilID3',
#  'ldsMSL_meanIQ3',
#  'ldsMSL_rangeIQ3',
#  'ldsMSL_theilID3',
#  'ldsRea_meanIQ3',
#  'ldsRea_rangeIQ3',
#  'ldsRea_theilID3',
#  'mtdDeg_meanIQ3',
#  'mtdDeg_rangeIQ3',
#  'mtdDeg_theilID3',
#  'lcdMes_meanIQ3',
#  'lcdMes_rangeIQ3',
#  'lcdMes_theilID3',
#  'linP3W_meanIQ3',
#  'linP3W_rangeIQ3',
#  'linP3W_theilID3',
#  'linP4W_meanIQ3',
#  'linP4W_rangeIQ3',
#  'linP4W_theilID3',
#  'linPDE_meanIQ3',
#  'linPDE_rangeIQ3',
#  'linPDE_theilID3',
#  'lcnClo_meanIQ3',
#  'lcnClo_rangeIQ3',
#  'lcnClo_theilID3',
#  'ldsCDL_meanIQ3',
#  'ldsCDL_rangeIQ3',
#  'ldsCDL_theilID3',
#  'xcnSCl_meanIQ3',
#  'xcnSCl_rangeIQ3',
#  'xcnSCl_theilID3',
#  'mtdMDi_meanIQ3',
#  'mtdMDi_rangeIQ3',
#  'mtdMDi_theilID3',
#  'lddNDe_meanIQ3',
#  'lddNDe_rangeIQ3',
#  'lddNDe_theilID3',
#  'linWID_meanIQ3',
#  'linWID_rangeIQ3',
#  'linWID_theilID3',
#  'lddRea_meanIQ3',
#  'lddRea_rangeIQ3',
#  'lddRea_theilID3',
#  'lddARe_meanIQ3',
#  'lddARe_rangeIQ3',
#  'lddARe_theilID3',
#  'sddAre_meanIQ3',
#  'sddAre_rangeIQ3',
#  'sddAre_theilID3',
#  'midRea_meanIQ3',
#  'midRea_rangeIQ3',
#  'midRea_theilID3',
#  'midAre_meanIQ3',
#  'midAre_rangeIQ3',
#  'midAre_theilID3']

# %%
gdf[pat].reset_index().to_csv('files/AMS/context_data.csv')

# %%
simpson = pd.read_csv('files/AMS/simpson.csv', index_col=0)

# %%
simpson
# Out:
#        sdcLAL_simpson  sdcAre_simpson  sicFAR_simpson  mdcAre_simpson  \
# uID
# 0            1.000000        1.000000        1.000000        1.000000
# 1            1.000000        1.000000        1.000000        1.000000
# 2            0.387755        0.346939        1.000000        0.551020
# 3            0.256198        0.272727        1.000000        0.537190
# 4            0.387755        0.346939        1.000000        0.551020
# ...               ...             ...             ...             ...
# 19452        0.342561        0.640138        0.695502        0.508651
# 19453        0.304688        0.539062        0.593750        0.468750
# 19454        0.327977        0.586957        0.460302        0.380907
# 19455        0.327977        0.586957        0.460302        0.380907
# 19457        0.391003        0.617647        0.461938        0.446367
#
#        licGDe_simpson  ltcWRB_simpson  stcSAl_simpson  sdbHei_simpson  \
# uID
# 0            1.000000             1.0        1.000000        1.000000
# 1            1.000000             1.0        1.000000        1.000000
# 2            1.000000             1.0        0.428571        1.000000
# 3            1.000000             1.0        0.256198        1.000000
# 4            1.000000             1.0        0.428571        1.000000
# ...               ...             ...             ...             ...
# 19452        0.515571             1.0        0.418685        0.889273
# 19453        0.570312             1.0        0.390625        0.773438
# 19454        0.534026             1.0        0.599244        0.762760
# 19455        0.534026             1.0        0.599244        0.762760
# 19457        0.584775             1.0        0.607266        0.833910
#
#        sdbAre_simpson  sdbVol_simpson  ...  ldsCDL_simpson  xcnSCl_simpson  \
# uID                                    ...
# 0            1.000000        1.000000  ...        1.000000        1.000000
# 1            1.000000        1.000000  ...        1.000000        1.000000
# 2            0.510204        0.591837  ...        0.591837        1.000000
# 3            0.504132        0.834711  ...        1.000000        1.000000
# 4            0.510204        0.591837  ...        0.591837        1.000000
# ...               ...             ...  ...             ...             ...
# 19452        0.792388        0.709343  ...        1.000000        0.404844
# 19453        0.679688        0.601562  ...        1.000000        0.367188
# 19454        0.639887        0.603970  ...        0.547259        0.386578
# 19455        0.639887        0.603970  ...        0.547259        0.386578
# 19457        0.695502        0.648789  ...        0.610727        0.392734
#
#        mtdMDi_simpson  lddNDe_simpson  linWID_simpson  lddRea_simpson  \
# uID
# 0            1.000000        1.000000        1.000000        1.000000
# 1            1.000000        1.000000        1.000000        1.000000
# 2            1.000000        1.000000        1.000000        0.591837
# 3            1.000000        1.000000        1.000000        1.000000
# 4            1.000000        1.000000        1.000000        0.591837
# ...               ...             ...             ...             ...
# 19452        0.640138        1.000000        1.000000        0.584775
# 19453        0.695312        1.000000        1.000000        0.531250
# 19454        0.354442        0.957467        0.916824        0.327977
# 19455        0.354442        0.957467        0.916824        0.327977
# 19457        0.434256        0.942907        0.942907        0.354671
#
#        lddARe_simpson  sddAre_simpson  midRea_simpson  midAre_simpson
# uID
# 0            1.000000        1.000000        1.000000        1.000000
# 1            1.000000        1.000000        1.000000        1.000000
# 2            0.591837        0.591837        0.591837        0.591837
# 3            1.000000        1.000000        1.000000        1.000000
# 4            0.591837        0.591837        0.591837        0.591837
# ...               ...             ...             ...             ...
# 19452        0.508651        0.584775        0.889273        0.889273
# 19453        0.460938        0.531250        0.781250        0.882812
# 19454        0.444234        0.500945        0.414934        0.519849
# 19455        0.444234        0.500945        0.414934        0.519849
# 19457        0.531142        0.501730        0.391003        0.557093
#
# [252385 rows x 76 columns]

# %%
patterned = gdf[pat].merge(simpson, left_index=True, right_index=True)

# %%
patterned
# Out:
#        stcOri_meanIQ3  stcOri_rangeIQ3  stcOri_theilID3  sdcLAL_meanIQ3  \
# uID
# 0           27.539986         0.029926     5.903783e-07      215.728286
# 1           27.539986         0.029926     5.903783e-07      215.728286
# 2           27.376524        15.287430     6.786512e-02      165.119895
# 3           31.751999        14.433147     5.272121e-02      116.010516
# 4           27.376524        15.287430     6.786512e-02      165.119895
# ...               ...              ...              ...             ...
# 19452       37.493494         8.431445     6.527028e-03       80.571042
# 19453       37.011002         8.552335     6.648164e-03       81.405301
# 19454       41.082484         2.350902     3.195354e-03       62.124290
# 19455       41.082484         2.350902     3.195354e-03       62.124290
# 19457       40.871471         3.681925     3.522701e-03       52.938939
#
#        sdcLAL_rangeIQ3  sdcLAL_theilID3  sdcAre_meanIQ3  sdcAre_rangeIQ3  \
# uID
# 0             1.064598         0.000012    28314.656812       446.137978
# 1             1.064598         0.000012    28314.656812       446.137978
# 2            60.349187         0.013950    10780.086406      7414.403564
# 3            90.511917         0.112148     5078.970289      8830.542588
# 4            60.349187         0.013950    10780.086406      7414.403564
# ...                ...              ...             ...              ...
# 19452        79.614308         0.097360      646.907689       539.572227
# 19453        81.483123         0.101711      811.882093      1471.286550
# 19454        84.110704         0.138473      611.970826      1352.082203
# 19455        84.110704         0.138473      611.970826      1352.082203
# 19457        85.365806         0.162041      548.358138       696.910287
#
#        sdcAre_theilID3  sscCCo_meanIQ3  ...  ldsCDL_simpson  xcnSCl_simpson  \
# uID                                     ...
# 0             0.000124        0.774589  ...        1.000000        1.000000
# 1             0.000124        0.774589  ...        1.000000        1.000000
# 2             0.054318        0.481731  ...        0.591837        1.000000
# 3             0.392929        0.495462  ...        1.000000        1.000000
# 4             0.054318        0.481731  ...        0.591837        1.000000
# ...                ...             ...  ...             ...             ...
# 19452         0.176220        0.216770  ...        1.000000        0.404844
# 19453         0.329740        0.276944  ...        1.000000        0.367188
# 19454         0.496895        0.274728  ...        0.547259        0.386578
# 19455         0.496895        0.274728  ...        0.547259        0.386578
# 19457         0.454435        0.299230  ...        0.610727        0.392734
#
#        mtdMDi_simpson  lddNDe_simpson  linWID_simpson  lddRea_simpson  \
# uID
# 0            1.000000        1.000000        1.000000        1.000000
# 1            1.000000        1.000000        1.000000        1.000000
# 2            1.000000        1.000000        1.000000        0.591837
# 3            1.000000        1.000000        1.000000        1.000000
# 4            1.000000        1.000000        1.000000        0.591837
# ...               ...             ...             ...             ...
# 19452        0.640138        1.000000        1.000000        0.584775
# 19453        0.695312        1.000000        1.000000        0.531250
# 19454        0.354442        0.957467        0.916824        0.327977
# 19455        0.354442        0.957467        0.916824        0.327977
# 19457        0.434256        0.942907        0.942907        0.354671
#
#        lddARe_simpson  sddAre_simpson  midRea_simpson  midAre_simpson
# uID
# 0            1.000000        1.000000        1.000000        1.000000
# 1            1.000000        1.000000        1.000000        1.000000
# 2            0.591837        0.591837        0.591837        0.591837
# 3            1.000000        1.000000        1.000000        1.000000
# 4            0.591837        0.591837        0.591837        0.591837
# ...               ...             ...             ...             ...
# 19452        0.508651        0.584775        0.889273        0.889273
# 19453        0.460938        0.531250        0.781250        0.882812
# 19454        0.444234        0.500945        0.414934        0.519849
# 19455        0.444234        0.500945        0.414934        0.519849
# 19457        0.531142        0.501730        0.391003        0.557093
#
# [252385 rows x 298 columns]

# %%
list(patterned.columns)
# Out:
# ['stcOri_meanIQ3',
#  'stcOri_rangeIQ3',
#  'stcOri_theilID3',
#  'sdcLAL_meanIQ3',
#  'sdcLAL_rangeIQ3',
#  'sdcLAL_theilID3',
#  'sdcAre_meanIQ3',
#  'sdcAre_rangeIQ3',
#  'sdcAre_theilID3',
#  'sscCCo_meanIQ3',
#  'sscCCo_rangeIQ3',
#  'sscCCo_theilID3',
#  'sscERI_meanIQ3',
#  'sscERI_rangeIQ3',
#  'sscERI_theilID3',
#  'sicCAR_meanIQ3',
#  'sicCAR_rangeIQ3',
#  'sicCAR_theilID3',
#  'sicFAR_meanIQ3',
#  'sicFAR_rangeIQ3',
#  'sicFAR_theilID3',
#  'mtcWNe_meanIQ3',
#  'mtcWNe_rangeIQ3',
#  'mtcWNe_theilID3',
#  'mdcAre_meanIQ3',
#  'mdcAre_rangeIQ3',
#  'mdcAre_theilID3',
#  'licGDe_meanIQ3',
#  'licGDe_rangeIQ3',
#  'licGDe_theilID3',
#  'ltcWRB_meanIQ3',
#  'ltcWRB_rangeIQ3',
#  'ltcWRB_theilID3',
#  'stcSAl_meanIQ3',
#  'stcSAl_rangeIQ3',
#  'stcSAl_theilID3',
#  'sdbHei_meanIQ3',
#  'sdbHei_rangeIQ3',
#  'sdbHei_theilID3',
#  'sdbAre_meanIQ3',
#  'sdbAre_rangeIQ3',
#  'sdbAre_theilID3',
#  'sdbVol_meanIQ3',
#  'sdbVol_rangeIQ3',
#  'sdbVol_theilID3',
#  'sdbPer_meanIQ3',
#  'sdbPer_rangeIQ3',
#  'sdbPer_theilID3',
#  'sdbCoA_meanIQ3',
#  'sdbCoA_rangeIQ3',
#  'sdbCoA_theilID3',
#  'ssbFoF_meanIQ3',
#  'ssbFoF_rangeIQ3',
#  'ssbFoF_theilID3',
#  'ssbVFR_meanIQ3',
#  'ssbVFR_rangeIQ3',
#  'ssbVFR_theilID3',
#  'ssbCCo_meanIQ3',
#  'ssbCCo_rangeIQ3',
#  'ssbCCo_theilID3',
#  'ssbCor_meanIQ3',
#  'ssbCor_rangeIQ3',
#  'ssbCor_theilID3',
#  'ssbSqu_meanIQ3',
#  'ssbSqu_rangeIQ3',
#  'ssbSqu_theilID3',
#  'ssbERI_meanIQ3',
#  'ssbERI_rangeIQ3',
#  'ssbERI_theilID3',
#  'ssbElo_meanIQ3',
#  'ssbElo_rangeIQ3',
#  'ssbElo_theilID3',
#  'stbOri_meanIQ3',
#  'stbOri_rangeIQ3',
#  'stbOri_theilID3',
#  'mtbSWR_meanIQ3',
#  'mtbSWR_rangeIQ3',
#  'mtbSWR_theilID3',
#  'mtbAli_meanIQ3',
#  'mtbAli_rangeIQ3',
#  'mtbAli_theilID3',
#  'mtbNDi_meanIQ3',
#  'mtbNDi_rangeIQ3',
#  'mtbNDi_theilID3',
#  'libNCo_meanIQ3',
#  'libNCo_rangeIQ3',
#  'libNCo_theilID3',
#  'ldbPWL_meanIQ3',
#  'ldbPWL_rangeIQ3',
#  'ldbPWL_theilID3',
#  'ltbIBD_meanIQ3',
#  'ltbIBD_rangeIQ3',
#  'ltbIBD_theilID3',
#  'ltcBuA_meanIQ3',
#  'ltcBuA_rangeIQ3',
#  'ltcBuA_theilID3',
#  'ssbCCM_meanIQ3',
#  'ssbCCM_rangeIQ3',
#  'ssbCCM_theilID3',
#  'ssbCCD_meanIQ3',
#  'ssbCCD_rangeIQ3',
#  'ssbCCD_theilID3',
#  'stbCeA_meanIQ3',
#  'stbCeA_rangeIQ3',
#  'stbCeA_theilID3',
#  'stbSAl_meanIQ3',
#  'stbSAl_rangeIQ3',
#  'stbSAl_theilID3',
#  'ldkAre_meanIQ3',
#  'ldkAre_rangeIQ3',
#  'ldkAre_theilID3',
#  'ldkPer_meanIQ3',
#  'ldkPer_rangeIQ3',
#  'ldkPer_theilID3',
#  'lskCCo_meanIQ3',
#  'lskCCo_rangeIQ3',
#  'lskCCo_theilID3',
#  'lskERI_meanIQ3',
#  'lskERI_rangeIQ3',
#  'lskERI_theilID3',
#  'lskCWA_meanIQ3',
#  'lskCWA_rangeIQ3',
#  'lskCWA_theilID3',
#  'ltkOri_meanIQ3',
#  'ltkOri_rangeIQ3',
#  'ltkOri_theilID3',
#  'ltkWNB_meanIQ3',
#  'ltkWNB_rangeIQ3',
#  'ltkWNB_theilID3',
#  'likWBB_meanIQ3',
#  'likWBB_rangeIQ3',
#  'likWBB_theilID3',
#  'sdsLen_meanIQ3',
#  'sdsLen_rangeIQ3',
#  'sdsLen_theilID3',
#  'sdsSPW_meanIQ3',
#  'sdsSPW_rangeIQ3',
#  'sdsSPW_theilID3',
#  'sdsSPH_meanIQ3',
#  'sdsSPH_rangeIQ3',
#  'sdsSPH_theilID3',
#  'sdsSPR_meanIQ3',
#  'sdsSPR_rangeIQ3',
#  'sdsSPR_theilID3',
#  'sdsSPO_meanIQ3',
#  'sdsSPO_rangeIQ3',
#  'sdsSPO_theilID3',
#  'sdsSWD_meanIQ3',
#  'sdsSWD_rangeIQ3',
#  'sdsSWD_theilID3',
#  'sdsSHD_meanIQ3',
#  'sdsSHD_rangeIQ3',
#  'sdsSHD_theilID3',
#  'sssLin_meanIQ3',
#  'sssLin_rangeIQ3',
#  'sssLin_theilID3',
#  'sdsAre_meanIQ3',
#  'sdsAre_rangeIQ3',
#  'sdsAre_theilID3',
#  'sisBpM_meanIQ3',
#  'sisBpM_rangeIQ3',
#  'sisBpM_theilID3',
#  'misRea_meanIQ3',
#  'misRea_rangeIQ3',
#  'misRea_theilID3',
#  'mdsAre_meanIQ3',
#  'mdsAre_rangeIQ3',
#  'mdsAre_theilID3',
#  'ldsMSL_meanIQ3',
#  'ldsMSL_rangeIQ3',
#  'ldsMSL_theilID3',
#  'ldsRea_meanIQ3',
#  'ldsRea_rangeIQ3',
#  'ldsRea_theilID3',
#  'mtdDeg_meanIQ3',
#  'mtdDeg_rangeIQ3',
#  'mtdDeg_theilID3',
#  'lcdMes_meanIQ3',
#  'lcdMes_rangeIQ3',
#  'lcdMes_theilID3',
#  'linP3W_meanIQ3',
#  'linP3W_rangeIQ3',
#  'linP3W_theilID3',
#  'linP4W_meanIQ3',
#  'linP4W_rangeIQ3',
#  'linP4W_theilID3',
#  'linPDE_meanIQ3',
#  'linPDE_rangeIQ3',
#  'linPDE_theilID3',
#  'lcnClo_meanIQ3',
#  'lcnClo_rangeIQ3',
#  'lcnClo_theilID3',
#  'ldsCDL_meanIQ3',
#  'ldsCDL_rangeIQ3',
#  'ldsCDL_theilID3',
#  'xcnSCl_meanIQ3',
#  'xcnSCl_rangeIQ3',
#  'xcnSCl_theilID3',
#  'mtdMDi_meanIQ3',
#  'mtdMDi_rangeIQ3',
#  'mtdMDi_theilID3',
#  'lddNDe_meanIQ3',
#  'lddNDe_rangeIQ3',
#  'lddNDe_theilID3',
#  'linWID_meanIQ3',
#  'linWID_rangeIQ3',
#  'linWID_theilID3',
#  'lddRea_meanIQ3',
#  'lddRea_rangeIQ3',
#  'lddRea_theilID3',
#  'lddARe_meanIQ3',
#  'lddARe_rangeIQ3',
#  'lddARe_theilID3',
#  'sddAre_meanIQ3',
#  'sddAre_rangeIQ3',
#  'sddAre_theilID3',
#  'midRea_meanIQ3',
#  'midRea_rangeIQ3',
#  'midRea_theilID3',
#  'midAre_meanIQ3',
#  'midAre_rangeIQ3',
#  'midAre_theilID3',
#  'sdcLAL_simpson',
#  'sdcAre_simpson',
#  'sicFAR_simpson',
#  'mdcAre_simpson',
#  'licGDe_simpson',
#  'ltcWRB_simpson',
#  'stcSAl_simpson',
#  'sdbHei_simpson',
#  'sdbAre_simpson',
#  'sdbVol_simpson',
#  'sdbPer_simpson',
#  'sdbCoA_simpson',
#  'ssbFoF_simpson',
#  'ssbVFR_simpson',
#  'ssbCor_simpson',
#  'mtbAli_simpson',
#  'mtbNDi_simpson',
#  'libNCo_simpson',
#  'ldbPWL_simpson',
#  'ltbIBD_simpson',
#  'ltcBuA_simpson',
#  'ssbCCM_simpson',
#  'ssbCCD_simpson',
#  'stbCeA_simpson',
#  'stbSAl_simpson',
#  'sscERI_simpson',
#  'ssbERI_simpson',
#  'stcOri_simpson',
#  'sscCCo_simpson',
#  'sscERI_simpson.1',
#  'sicCAR_simpson',
#  'mtcWNe_simpson',
#  'ssbCCo_simpson',
#  'ssbSqu_simpson',
#  'ssbERI_simpson.1',
#  'ssbElo_simpson',
#  'stbOri_simpson',
#  'mtbSWR_simpson',
#  'ldkAre_simpson',
#  'ldkPer_simpson',
#  'lskCCo_simpson',
#  'lskERI_simpson',
#  'lskCWA_simpson',
#  'ltkOri_simpson',
#  'ltkWNB_simpson',
#  'likWBB_simpson',
#  'sdsLen_simpson',
#  'sdsSPW_simpson',
#  'sdsSPH_simpson',
#  'sdsSPR_simpson',
#  'sdsSPO_simpson',
#  'sdsSWD_simpson',
#  'sdsSHD_simpson',
#  'sssLin_simpson',
#  'sdsAre_simpson',
#  'sisBpM_simpson',
#  'misRea_simpson',
#  'mdsAre_simpson',
#  'ldsMSL_simpson',
#  'ldsRea_simpson',
#  'mtdDeg_simpson',
#  'lcdMes_simpson',
#  'linP3W_simpson',
#  'linP4W_simpson',
#  'linPDE_simpson',
#  'lcnClo_simpson',
#  'ldsCDL_simpson',
#  'xcnSCl_simpson',
#  'mtdMDi_simpson',
#  'lddNDe_simpson',
#  'linWID_simpson',
#  'lddRea_simpson',
#  'lddARe_simpson',
#  'sddAre_simpson',
#  'midRea_simpson',
#  'midAre_simpson']

# %%
patterned = patterned.drop(columns=['ssbERI_simpson.1'])

# %%
patterned.shape
# Out:
# (252385, 296)

# %%
patterned.to_csv('files/AMS/context_data.csv')
